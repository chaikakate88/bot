#
# **В рамках сохранения популяции птиц в 2023 году необходимо предпринять ряд мер, таких как:**
#
# 1. Создание заповедных территорий и парков, где будет курироваться состояние экосистем и охраняться обитающие там виды птиц.
#
# 2. Организация экологических компаний , которые будут собирать информацию о регулярном уменьшении числа птиц, выселяться в места размножения птиц и пытаясь предотвратить их исчезновение.
#
# 3. Популяризация среди населения и изучение причин устранения птиц и угроз их исчезновения.
#
# 4. Ограничение использования пестицидов, предотвращение загрязнения водоемов и других мест, где обитают птицы.
#
# 5. Исследование и разработка более эффективных методов воздействия на численность птиц, в том числе на интенсивную вырубку лесов и использование инновационных методов сохранения экосистем.

# %% [markdown]
# Программа определитель перьев птиц может помочь сохранить популяцию разных видов птиц, предоставляя информацию о различных видов перьев и техниках их определения. Это позволит людям, которые занимаются наблюдением за птицами, лучше определять виды птиц в их естественной среде обитания, что способствует сбору более точных данных о численности птиц. Эти данные могут использоваться для определения уровня угрозы, которые воздействуют на популяции птиц и для разработки мер по их защите. Кроме того, приложение может рекомендовать места наблюдения за определенными видами птиц для туристов и любителей птиц. Это может способствовать развитию экотуризма и позитивно влиять на экономику региона.

# %% [markdown]
# **Программа определитель перьев птиц дикой природы может быть полезной для национального парка в следующих аспектах:**
#
# 1. Исследование биоразнообразия: Определитель перьев может помочь ученым и руководству национального парка в исследовании разнообразия птиц в парке.
# Сбор данных о различных видов птиц в парке может помочь в понимании их поведения, использования местности и скорректировать управление парком.
#
# 2. Привлечение туристов: Когда посетители национального парка могут определить перья дикой природы, это может добавить к знаниям человека о природе и ее красоте.
# Прохождение программы определения перьев может помочь в привлечении любителей природы в парк и увеличении его популярности.
#
# 3. Обучение гидов: Определитель перьев может быть полезным инструментом обучения гидов, которые объясняют и демонстрируют живой мир национального парка туристам.
# Чем более глубокое знание у гида имеется об окружающей природе, тем более интересными и понятными могут стать его рассказы.
#
# 4. Сбор данных для мониторинга: Определитель перьев может помочь в сборе данных о разных видах птиц в парке.
# Эти данные могут использоваться для мониторинга здоровья их популяций в рамках природы парка.
# Такие данные в свою очередь могут быть использованы для принятия решений на уровне управления парка в будущем.
#
# Таким образом, программа определителя перьев дикой природы может принести много пользы для управления и поддержания биоразнообразия национального парка.

# %% [markdown]
# **С помощью программы определителя перьев птиц дикой природы туристы смогут:**
#
# 1. Определять виды диких птиц, которые они видят во время туристических поездок, и узнавать больше о поведении их видов.
#
# 2. Увеличивать свой уровень знаний о дикой природе и узнавать новые факты о ее жителях.
#
# 3. Принимать более глубокое участие в природных экскурсиях и работать с экспертами, чтобы изучать и защищать животный мир.
#
# 4. Сохранять записи о своих наблюдениях и сравнивать их с записями других туристов и экспертов. Это может помочь в лучшем понимании и сохранении биоразнообразия птиц.
#
# 5. Получать возможность более детально изучать птиц, которые живут в регионе, куда они путешествуют. Это может помочь туристам более глубоко погрузиться в местную культуру и экосистему.

# %% [markdown]
# **Библиотеки Python, которые могут использоваться для решения этой задачи:**
#
# 1. **OpenCV** - библиотека компьютерного зрения, которая может быть использована для обработки изображений и поиска признаков.
#
# 2. **TensorFlow** - библиотека машинного обучения, которая может использоваться для обучения модели классификации перьев.
#
# 3. **PyTorch** - альтернативная библиотека машинного обучения, которая также может быть использована для обучения модели классификации.
#
# 4. **SciPy** - библиотека для научных вычислений, которая может использоваться для анализа спектральных характеристик перьев.
#
# 5. **NumPy** - библиотека для операций с массивами, которая может быть использована для работы с изображениями и обработки данных.

# %% [markdown]
# **Этапы реализации проекта:**

# %% [markdown]
# **1.** *Подготовка данных: необходимо выбрать набор данных, который содержит изображения птиц с различными типами перьев. Далее, изображения должны быть разделены на обучающий и тестовый наборы.*

# %% [markdown]
# **Вот некоторые источники данных, где можно найти наборы данных о птицах дикой природы:**
#
# 1. **Global Biodiversity Information Facility (GBIF)**: это крупнейший открытый источник данных об определенных видах животных, включая птиц. Сайт предлагает доступ к миллионам записей, собранных более чем 14000 научных организаций по всему миру.
#
# 2. **Cornell Lab of Ornithology: Cornell University** является одной из ведущих организаций в области исследования и защиты птиц. На сайте доступны различные наборы данных и информация о птицах.
#
# 3. **eBird**: это проект при Cornell Lab of Ornithology, где люди могут загружать свои наблюдения за птицами и делать свои наблюдения доступными для других исследователей. Данные могут быть использованы для анализа изменения количества и распределения птиц на определенной территории.
#
# 4. **BirdLife International**: этот сайт предлагает информацию о различных видах птиц по всему миру, а также наборы данных, в том числе о распределении птиц и оценке их статуса.
#
# 5. **The Avian Knowledge Network**: это проект, разработанный для сбора и обработки данных об изменениях в распределении и количестве птиц. Сайт предоставляет доступ к отчетам, картам и другим данным.
#
# 6. **IUCN Red List**: это база данных, которая содержит информацию о статусе защищенности и риске исчезновения различных видов животных, включая птиц. В базе данных доступны данные о глобальных трендах изменения количества и распространения видов.
#
# Эти и другие ресурсы могут использоваться для создания набора данных птиц дикой природы.

# %% [markdown]
# **2.** *Создание модели: в TensorFlow модель может быть создана с помощью API Keras. Например, следующий код создает нейронную сеть с одним скрытым слоем:*

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10)
])

# %% [markdown]
# **3.** *Обучение модели: после создания модели необходимо обучить ее на обучающем наборе данных. Например, следующий код компилирует модель и обучает ее:*

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=10)

# %% [markdown]
# **4.** *Оценка модели: после обучения модель необходимо оценить на тестовом наборе данных. Например, следующий код оценивает точность модели на тестовом наборе данных:*

# %%
test_loss, test_accuracy = model.evaluate(test_images, test_labels, verbose=2)
print('\nTest accuracy:', test_accuracy)

# %% [markdown]
# **5.** *Использование модели: после успешного обучения и оценки точности модель может быть использована для классификации новых изображений. Например, следующий код классифицирует новое изображение:*

# %%
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
predictions = probability_model.predict(new_image)

# %% [markdown]
# **Классификация изображений видов перьев птиц с использованием Keras на Python**

# %%
# !pip install tensorflow
# !pip install keras
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Импортируем библиотеки**

# %%
import keras
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import preprocess_input
from google.colab import files

# %%
files.upload()
# !mkdir -p  ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d gpiosenka/100-bird-species
# Out:
#      <input type="file" id="files-5ebca965-8319-4c81-85d0-ff6f01b5ec11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ebca965-8319-4c81-85d0-ff6f01b5ec11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
local_zip = '/content/100-bird-species.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content/')
zip_ref.close()

# %%
train_datagen = ImageDataGenerator(
        preprocessing_function=preprocess_input,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True)
train_generator = train_datagen.flow_from_directory('/content/train',target_size=(224, 224),batch_size=64,class_mode='categorical')
#Creating generator for Validation DataSet
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_generator = val_datagen.flow_from_directory('/content/valid',target_size=(224, 224),batch_size=32,class_mode='categorical')
#Creating generator for Test DataSet
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_generator = test_datagen.flow_from_directory('/content/test',target_size=(224, 224),batch_size=32,class_mode='categorical')
# Out:
# Found 82724 images belonging to 515 classes.
# Found 2575 images belonging to 515 classes.
# Found 2575 images belonging to 515 classes.

# %%
base_model=keras.applications.VGG16(include_top=False, weights="imagenet", input_shape=(224,224,3))

# %%
base_model.trainable = False

# %%
from keras.models import Sequential
from keras.layers import Dense,Flatten,Dropout
model=Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(2048,activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.35))
model.add(Dense(2048,activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.35))
model.add(Dense(515,activation='softmax',kernel_initializer='glorot_normal'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 2048)              51382272
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 2048)              4196352
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 515)               1055235
#
# ...
# Total params: 71,348,547
# Trainable params: 56,633,859
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(optimizer=keras.optimizers.Adam(1e-4),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(train_generator,epochs=1,validation_data=val_generator,workers=100,use_multiprocessing=True)

# %% [markdown]
# ![изображение_2023-04-17_185952049.png](data:image/png;base64,...)

# %% [markdown]
# **Визуализация данных**

# %%
import matplotlib.pyplot as plt
#Loss
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend()
plt.show()
#Accuracy
plt.plot(history.history['accuracy'],label='acc')
plt.plot(history.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()

# %% [markdown]
# **При визуализации данных получается следующий график:**

# %% [markdown]
# ![изображение_2023-04-17_165010092.png](data:image/png;base64,...)

# %% [markdown]
# **Сохраняем модель**

# %%
model.save("/content/drive/My Drive/yolov3/birds.h5")

# %%
model.evaluate(test_generator,use_multiprocessing=True,workers=10)

# %% [markdown]
# ![изображение_2023-04-17_190100792.png](data:image/png;base64,...)

# %% [markdown]
# **Помимо определителя, программа будет содержать общую теоретическую часть и памятку о важности сохранения популяции птиц в природе:**

# %% [markdown]
# **Перо** — накожное роговое образование птиц.

# %% [markdown]
# **Эволюционное происхождение перьев**
#
# Начальные стадии эмбрионального развития пера сходны с развитием чешуи. Поэтому ранее считалось, что перья возникли в результате эволюционных преобразований чешуи.
#
# Самым ранним из известных перьев, вероятно, является окаменелость, описанная под названием Praeornis sharovi.
#
# Эволюционное происхождение перьев можно проследить, начиная с хищных динозавров синозавроптерикса и дилонга, покрытых волокнистым пухом. У каудиптерикса, синорнитозавра и микрораптора можно наблюдать настоящие перья. Возможно, перья появились гораздо раньше, поскольку протоперья обнаружены у древнего птицетазового динозавра кулиндадромея.

# %% [markdown]
# **Виды перьев**
#
# В зависимости от предназначения и местоположения различают три основных вида перьев: пух, контурные и маховые перья. Основные виды, в свою очередь, подразделяются на:
#
# **Пух:**
#
# *собственно пух* — перо с мягким стержнем и слабым развитием опахала, находится на теле, предназначен для теплоизоляции;
# пуховые перья — перья промежуточного типа между контурными и пухом, имеют относительно длинный и упругий стержень, но их бородки не сцеплены в пластинку опахала.
#
# **Контурные перья:**
#
# *кроющие* — на теле, делают форму тела обтекаемой.
#
# **Маховые перья:**
#
# *первого порядка* — на крыльях. Прикрепляются к кисти. У летающих птиц их обычно 10 (дятлы), 11 (утки) или 12 (поганки);
#
# *второго порядка* — на крыльях. Сидят на предплечье. Их количество варьируется от 6 (колибри) до 37 (альбатросы);
#
# *рулевые* — на хвосте. Их бывает от 8-10 у дятла, 24 у лебедя и до 26 у некоторых бекасов.
#
# **Другие разновидности:**
#
# *вибриссы* — перья, которые утратили бородки, но сохранили стержень. Они располагаются у основания клюва и выполняют осязательную функцию;
#
# *«украшающие»* — разнообразные видоизменения контурного пера, характерные для брачного наряда самцов.

# %% [markdown]
# **Строение и рост пера**
#
# Перья — роговые накожные образования, растущие из расположенных рядами углублений кожи, называемых птерилиями. Лишь у немногих нелетающих птиц, как например, у пингвинов, птерилии не выражены, а перья растут равномерно по всему телу.
#
# Контурные перья покрывают всё тело птицы и имеют хорошо развитый плотный стержень, основание которого — полый очин — охватывается находящейся в коже перьевой сумкой. Глубина перьевой сумки больше у крупных перьев. От стержня отходят упругие бородки, которые несут бородочки с крючочками, которые сцепляются с крючочками соседних бородок, образуя опахало пера. В самой нижней части пера бородки обычно являются более мягкими и длинными, а их бородочки не имеют крючочков — данный участок называют пуховой частью опахала. Особенности строения перьев могут варьировать у разных групп птиц. Так виды, живущие в суровых температурных условиях, обычно обладают более сильно развитой пуховой частью опахала. У большинства птиц имеются пуховые перья (стержень мягкий) и пух (стержень совсем редуцирован), мягкие и длинные бородки которых несут мягкие бородочки, лишённые крючочков, из-за чего сцепленного опахала не образуется. Между типичным пером, пуховым пером и пухом существуют разнообразные промежуточные типы. Пуховые перья обычно располагаются по птерилиям. Пух относительно равномерно покрывает всё тело (веслоногие, гусеобразные, многие хищные птицы и др.), либо имеется только на аптериях (цапли, куриные, совы, многие воробьиные и др.), либо — только на птерилиях (тинаму). Обычно пуховые перья и пух прикрыты контурными перьями. Только у немногих птиц (грифы, марабу и др.) голова и часть шеи покрыты только пухом. Нитевидные перья расположены под контурными перьями, обладают длинным тонким стержнем и редуцированными бородками. Видимо, они выполняют осязательную функцию.
#
